# %% [markdown]
# ## Boolean Arithemtic

# %% [markdown]
# _Boolean Arithmetic_ is the arithmetic of true and flase logic. A boolean or logical value can either be True or False.

# %%
A = True
B = False

# %%
A
# Out:
# True

# %%
B
# Out:
# False

# %%
A or B
# Out:
# True

# %%
A and B
# Out:
# False

# %%
not A
# Out:
# False

# %%
not B
# Out:
# True

# %%
A == B
# Out:
# False

# %%
A != B
# Out:
# True

# %%
C = False

# %%
A or (C and B)
# Out:
# True

# %%
(A and B) or C
# Out:
# False

# %%
a ='me'
